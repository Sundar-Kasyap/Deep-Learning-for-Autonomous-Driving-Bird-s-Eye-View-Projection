# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import cv2
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
from keras.utils import to_categorical
import os

import time
import keras.backend as K
from keras import Input, Model
from keras.layers import Convolution2D, LeakyReLU, BatchNormalization, Conv2D, UpSampling2D, Subtract, Concatenate, Softmax, Dropout, Activation,MaxPooling2D, Flatten, Dense, Lambda, Reshape, concatenate, ZeroPadding2D, Cropping2D
from keras.optimizers import Adam
import tensorflow as tf

# %%
def plot_cameras(sequence_number):

  rows = 2
  columns = 3
  fig=plt.figure(figsize=(10, 10))
  imgs = []
  cameras = ['left', 'front','right', 'back','top']

  for i, camera in enumerate(cameras):
    sample = np.load(f"/content/drive/MyDrive/Thesis/data2/{camera}/{sequence_number}.npy")
    fig.add_subplot(rows, columns, i+1)
    plt.imshow(sample, cmap='gist_stern')

  plt.show()

# %%
plot_cameras(10)

# %%
import os

def get_paths(val_size=2000):

  img_paths = []

  for i in range(len(os.listdir('/content/drive/MyDrive/Thesis/data2/top'))):
    path = f'{i}.npy'
    img_paths.append(path)

  return pd.DataFrame({'path':img_paths[:-val_size]}), pd.DataFrame({'path':img_paths[-val_size:]})

# %%
img_paths_train, img_paths_val = get_paths()
img_paths_train
# Out:
#           path
# 0        0.npy
# 1        1.npy
# 2        2.npy
# 3        3.npy
# 4        4.npy
# ...        ...
# 7995  7995.npy
# 7996  7996.npy
# 7997  7997.npy
# 7998  7998.npy
# 7999  7999.npy
#
# [8000 rows x 1 columns]

# %%
img_paths_val
# Out:
#           path
# 0     8000.npy
# 1     8001.npy
# 2     8002.npy
# 3     8003.npy
# 4     8004.npy
# ...        ...
# 1995  9995.npy
# 1996  9996.npy
# 1997  9997.npy
# 1998  9998.npy
# 1999  9999.npy
#
# [2000 rows x 1 columns]

# %%
def img_to_categorical(img, needed_labels):

  cat = np.empty((img.shape[0], img.shape[1], len(needed_labels)))

  for channel, label in enumerate(needed_labels):
    cat[:, :, channel] = np.where(np.isin(img, label), 1, 0)

  return cat

def categorical_to_img(cat):

  img = np.argmax(cat, axis=-1)
  return img

needed_labels = [0, 1, 6, 7, 8, 10, 11]

# %%
from tensorflow.keras.utils import Sequence

class DataGenerator2D(Sequence):
    """Generates data for Keras
    Sequence based data generator. Suitable for building data generator for training and prediction.
    """
    def __init__(self, img_paths, base_path, to_fit=True, batch_size=32, shuffle=True, needed_classes = []):

        self.img_paths = img_paths.copy()
        self.base_path = base_path
        self.to_fit = to_fit
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.needed_classes = needed_classes
        self.on_epoch_end()

    def __len__(self):
        """Denotes the number of batches per epoch
        :return: number of batches per epoch
        """
        return int(len(self.img_paths) // self.batch_size)

    def __getitem__(self, index):
        """Generate one batch of data
        :param index: index of the batch
        :return: X and y when fitting. X only when predicting
        """
        # Generate indexes of the batch
        current_indexes = list(range(index * self.batch_size, (index + 1) * self.batch_size))
        img_paths_temp = self.img_paths[current_indexes]

        # Generate data
        X = self._generate_X(img_paths_temp)

        if self.to_fit:
            y = self._generate_y(img_paths_temp)
            return X, y
        else:
            return X

    def on_epoch_end(self):
        """Updates indexes after each epoch
        """
        if self.shuffle == True:
            indices = np.arange(len(self.img_paths))
            np.random.shuffle(indices)
            self.img_paths = self.img_paths[indices]
            self.img_paths.reset_index(drop=True, inplace=True)


    def _generate_X(self, img_paths_temp):
        """Generates data containing batch_size images
        :param img_paths_temp: list of label ids to load
        :return: batch of images
        """
        # Initialization

        X = []

        # Generate data
        for idx, path in zip(img_paths_temp.index, img_paths_temp):
            # Store sample
            img = self._load_image(path)
            X.append(img)

        return np.array(X)

    def _generate_y(self, img_paths_temp):

        y = []

        for idx, path in zip(img_paths_temp.index, img_paths_temp):
            # Store sample
            img = self._load_image(path, front=False)
            y.append(img)
        return np.array(y)

    def _load_image(self, image_path, front=True):

        if front:
          img_dir =  '/front/'
        else:
          img_dir =  '/top/'

        img = np.load(self.base_path + img_dir + image_path)
        img = img[::2, ::2]                                          # Downsampling image by factor of 2

        if not front:
          img = img[3:(img.shape[0]//2)]
          img = np.rot90(img)
          img = img[2:-2]                                           # Crop Image to make dimensions divisible by 8
          img = img_to_categorical(img, self.needed_classes)

          return img

        img = img[2:-2, 3:-3]                                       # Crop Image to make dimensions divisible by 8
        img = img_to_categorical(img, self.needed_classes)

        return img

# %%
train_generator = DataGenerator2D(img_paths_train['path'], '/content/drive/MyDrive/Thesis/data2', batch_size=32, shuffle=True, needed_classes=needed_labels)
val_generator = DataGenerator2D(img_paths_val['path'], '/content/drive/MyDrive/Thesis/data2', batch_size=1, shuffle=False, needed_classes=needed_labels)

# %%
# Test the generator

X, y = train_generator.__getitem__(0)
print(X.shape, y.shape)
# Out:
# (32, 96, 144, 7) (32, 96, 72, 7)

# %%
fig=plt.figure(figsize=(17, 17))
columns = 4
rows = 2
for i in range(1, columns*rows + 1):
    img = X[i-1]
    fig.add_subplot(rows, columns, i)
    plt.imshow(categorical_to_img(img), cmap='gist_stern', vmin=0, vmax=len(needed_labels)-1)
plt.show()

# %%
fig=plt.figure(figsize=(17, 17))
columns = 4
rows = 2
for i in range(1, columns*rows + 1):
    img = y[i-1]
    fig.add_subplot(rows, columns, i)
    plt.imshow(np.rot90(categorical_to_img(img), 3), cmap='gist_stern', vmin=0, vmax=len(needed_labels)-1)
plt.show()

# %% [markdown]
# #Model development (Sequential)

# %%
import time
import keras.backend as K
from keras import Input, Model
from keras.layers import Convolution2D, LeakyReLU, BatchNormalization, UpSampling2D, Subtract, Concatenate, Softmax, Dropout, Activation,MaxPooling2D, Flatten, Dense, Lambda, Reshape, concatenate, ZeroPadding2D, Cropping2D
from keras.optimizers import Adam
from keras import Sequential

# %%
def get_model(needed_labels):
    model = Sequential()

    model.add(Conv2D(16, (5, 5), strides=2, padding='same', input_shape=(96, 144, len(needed_labels))))
    model.add(BatchNormalization())
    model.add(LeakyReLU())

    model.add(Conv2D(32, (5, 5), strides=2, padding='same'))
    model.add(BatchNormalization())
    model.add(LeakyReLU())

    model.add(Conv2D(64, (3, 3), strides=2, padding='same'))
    model.add(BatchNormalization())
    model.add(LeakyReLU())

    model.add(Conv2D(64, (3, 3), strides=2, padding='same'))
    model.add(BatchNormalization())
    model.add(LeakyReLU())

    model.add(Conv2D(128, (3, 3), padding='same'))
    model.add(BatchNormalization())
    model.add(LeakyReLU())

    model.add(Conv2D(128, (3, 3), padding='same'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.2))

    model.add(UpSampling2D((2, 2)))
    model.add(Conv2D(128, (3, 3), padding='same'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.2))

    model.add(UpSampling2D((2, 2)))
    model.add(Conv2D(64, (3, 3), padding='same'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.2))

    model.add(Conv2D(64, (3, 3), padding='same'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.2))

    model.add(UpSampling2D((2, 2)))
    model.add(Conv2D(32, (3, 3), padding='same'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.2))

    model.add(Conv2D(32, (3, 3), padding='same'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.2))

    model.add(UpSampling2D((2, 1)))
    model.add(Conv2D(16, (5, 5), padding='same'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.2))

    model.add(Conv2D(len(needed_labels), (5, 5), activation='softmax', padding='same'))

    return model

model = get_model(needed_labels)
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 48, 72, 16)          │           2,816 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 48, 72, 16)          │              64 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu (LeakyReLU)              │ (None, 48, 72, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 24, 36, 32)          │          12,832 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 24, 36, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_1 (LeakyReLU)            │ (None, 24, 36, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 12, 18, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 12, 18, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_2 (LeakyReLU)            │ (None, 12, 18, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 6, 9, 64)            │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 6, 9, 64)            │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_3 (LeakyReLU)            │ (None, 6, 9, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 6, 9, 128)           │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 6, 9, 128)           │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_4 (LeakyReLU)            │ (None, 6, 9, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 6, 9, 128)           │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 6, 9, 128)           │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_5 (LeakyReLU)            │ (None, 6, 9, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ up_sampling2d (UpSampling2D)         │ (None, 12, 18, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (None, 12, 18, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_6                │ (None, 12, 18, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_6 (LeakyReLU)            │ (None, 12, 18, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ up_sampling2d_1 (UpSampling2D)       │ (None, 24, 36, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (None, 24, 36, 64)          │          73,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_7                │ (None, 24, 36, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_7 (LeakyReLU)            │ (None, 24, 36, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_8 (Conv2D)                    │ (None, 24, 36, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_8                │ (None, 24, 36, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_8 (LeakyReLU)            │ (None, 24, 36, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ up_sampling2d_2 (UpSampling2D)       │ (None, 48, 72, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_9 (Conv2D)                    │ (None, 48, 72, 32)          │          18,464 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_9                │ (None, 48, 72, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_9 (LeakyReLU)            │ (None, 48, 72, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_10 (Conv2D)                   │ (None, 48, 72, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_10               │ (None, 48, 72, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_10 (LeakyReLU)           │ (None, 48, 72, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ up_sampling2d_3 (UpSampling2D)       │ (None, 96, 72, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_11 (Conv2D)                   │ (None, 96, 72, 16)          │          12,816 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_11               │ (None, 96, 72, 16)          │              64 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_11 (LeakyReLU)           │ (None, 96, 72, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_12 (Conv2D)                   │ (None, 96, 72, 7)           │           2,807 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 597,223 (2.28 MB)
#  Trainable params: 595,687 (2.27 MB)
#  Non-trainable params: 1,536 (6.00 KB)

# %%
# Checking if the model can run at real time on current GPU at specified fps

from time import time
fps = 30

x = np.random.random((96, 144, len(needed_labels)))
start = time()

for i in range(fps):
  out = model.predict(np.array([x]))

print(time() - start)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 4.967928886413574

# %%
import os
from keras.optimizers import Nadam
from keras.callbacks import ModelCheckpoint, TensorBoard, EarlyStopping, LearningRateScheduler
from tensorflow.keras.optimizers.schedules import ExponentialDecay
from time import time

# Define the directories for logs and models
log_dir = "/content/drive/MyDrive/Thesis/self_driving(simp1)/logs(simp1)/BirdsEye{}".format(time())
model_dir = "/content/drive/MyDrive/Thesis/self_driving(simp1)/models(simp1)"
history_dir = "/content/drive/MyDrive/Thesis/self_driving(simp1)/history(simp1)"
# Ensure the directories exist
os.makedirs(log_dir, exist_ok=True)
os.makedirs(model_dir, exist_ok=True)
os.makedirs(history_dir, exist_ok=True)

# Define the learning rate decay schedule using ExponentialDecay
lr_schedule = ExponentialDecay(
    initial_learning_rate=1e-4,  # Starting learning rate
    decay_steps=100000,          # Number of steps before applying decay
    decay_rate=0.96,             # Decay rate (e.g., 0.96 reduces the LR by 4% every decay step)
    staircase=True               # Whether to apply decay in discrete steps or continuously
)

# Wrap the ExponentialDecay schedule in a function to return a Python float
def lr_schedule_function(epoch):
    return float(lr_schedule(epoch))  # Convert NumPy float to Python float

# Set up the Nadam optimizer with the learning rate decay
optimizer = Nadam(learning_rate=lr_schedule, beta_1=0.9, beta_2=0.999, epsilon=1e-08)

# Callbacks
tensorboard = TensorBoard(log_dir=log_dir)
early_stopping = EarlyStopping(monitor='val_loss', patience=30)

# Model checkpoint setup (to save the model during training)
filepath = model_dir + "/BirdsEye_cat_simple-2-saved-model-{epoch:02d}-{val_loss:.5f}.keras"  # Change to .keras extension
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False)

# Learning rate scheduler callback (for manual decay)
lr_scheduler = LearningRateScheduler(lr_schedule_function)

# Combine all callbacks into a list
callbacks_list = [checkpoint, tensorboard, early_stopping, lr_scheduler]

# Now you can use this optimizer and callbacks list in your model.fit() call

# %%
import tensorflow as tf

def dice_coef(y_true, y_pred, smooth=1):
    # Flatten the tensors using tf.reshape
    y_true_f = tf.reshape(y_true, [-1])  # Flatten the tensor to 1D
    y_pred_f = tf.reshape(y_pred, [-1])  # Flatten the tensor to 1D

    # Calculate the intersection
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth)

# Dice coefficient for multi-label classification
def dice_coef_multilabel(y_true, y_pred, numLabels=len(needed_labels)):
    dice = 0
    for index in range(0, numLabels):
        dice -= dice_coef(y_true[:, :, :, index], y_pred[:, :, :, index])
    return numLabels + dice

# SSIM (Structural Similarity Index) loss
def ssim_loss(y_true, y_pred):
    return 1 - tf.reduce_mean(tf.image.ssim(y_true, y_pred, 1.0))

# Custom loss function combining Dice loss and SSIM loss
def custom_loss(y_true, y_pred):
    return dice_coef_multilabel(y_true, y_pred) + 5 * ssim_loss(y_true, y_pred)

# %%
model.compile(optimizer='adam', loss=custom_loss, metrics=['categorical_accuracy'])

# %%
NUM_EPOCHS = 50

history = model.fit(train_generator, epochs=NUM_EPOCHS,
                    shuffle=True, callbacks=callbacks_list,
                    validation_data=val_generator)

# Save the training history
import pickle

history_save_path = '/content/drive/MyDrive/Thesis/self_driving(simp1)/history/history.pkl'

with open(history_save_path, 'wb') as f:
    pickle.dump(history.history, f)

print(f"History saved at {history_save_path}")
# Out:
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - categorical_accuracy: 0.4239 - loss: 8.4972
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1: saving model to /content/drive/MyDrive/Thesis/self_driving(simp1)/models(simp1)/BirdsEye_cat_simple-2-saved-model-01-5.71313.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 227s 346ms/step - categorical_accuracy: 0.4247 - loss: 8.4847 - val_categorical_accuracy: 0.7094 - val_loss: 5.7131 - learning_rate: 1.0000e-04
# Epoch 2/50
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - categorical_accuracy: 0.7189 - loss: 4.7454
# Epoch 2: saving model to /content/drive/MyDrive/Thesis/self_driving(simp1)/models(simp1)/BirdsEye_cat_simple-2-saved-model-02-4.87518.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 87s 340ms/step - categorical_accuracy: 0.7190 - loss: 4.7445 - val_categorical_accuracy: 0.7423 - val_loss: 4.8752 - learning_rate: 1.0000e-04
# Epoch 3/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - categorical_accuracy: 0.7497 - loss: 4.4286
# Epoch 3: saving model to /content/drive/MyDrive/Thesis/self_driving(simp1)/models(simp1)/BirdsEye_cat_simple-2-saved-model-03-4.43295.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 85s 333ms/step - categorical_accuracy: 0.7498 - loss: 4.4284 - val_categorical_accuracy: 0.7735 - val_loss: 4.4329 - learning_rate: 1.0000e-04
# Epoch 4/50
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - categorical_accuracy: 0.7749 - loss: 4.0527
# Epoch 4: saving model to /content/drive/MyDrive/Thesis/self_driving(simp1)/models(simp1)/BirdsEye_cat_simple-2-saved-model-04-4.11490.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 86s 336ms/step - categorical_accuracy: 0.7749 - loss: 4.0523 - val_categorical_accuracy: 0.7939 - val_loss: 4.1149 - learning_rate: 1.0000e-04
# Epoch 5/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - categorical_accuracy: 0.7871 - loss: 3.8560
# Epoch 5: saving model to /content/drive/MyDrive/Thesis/self_driving(simp1)/models(simp1)/BirdsEye_cat_simple-2-saved-model-05-3.98488.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 84s 329ms/step - categorical_accuracy: 0.7871 - loss: 3.8558 - val_categorical_accuracy: 0.7995 - val_loss: 3.9849 - learning_rate: 1.0000e-04
# Epoch 6/50
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - categorical_accuracy: 0.7998 - loss: 3.7028
# Epoch 6: saving model to /content/drive/MyDrive/Thesis/self_driving(simp1)/models(simp1)/BirdsEye_cat_simple-2-saved-model-06-3.73329.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 85s 331ms/step - categorical_accuracy: 0.7999 - loss: 3.7027 - val_categorical_accuracy: 0.8108 - val_loss: 3.7333 - learning_rate: 1.0000e-04
# Epoch 7/50
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - categorical_accuracy: 0.8103 - loss: 3.5941
# Epoch 7: saving model to /content/drive/MyDrive/Thesis/self_driving(simp1)/models(simp1)/BirdsEye_cat_simple-2-saved-model-07-3.75039.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 85s 332ms/step - categorical_accuracy: 0.8103 - loss: 3.5941 - val_categorical_accuracy: 0.8136 - val_loss: 3.7504 - learning_rate: 1.0000e-04
# Epoch 8/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - categorical_accuracy: 0.8160 - loss: 3.5364
# Epoch 8: saving model to /content/drive/MyDrive/Thesis/self_driving(simp1)/models(simp1)/BirdsEye_cat_simple-2-saved-model-08-3.66687.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 86s 336ms/step - categorical_accuracy: 0.8160 - loss: 3.5364 - val_categorical_accuracy: 0.8218 - val_loss: 3.6669 - learning_rate: 1.0000e-04
# Epoch 9/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - categorical_accuracy: 0.8197 - loss: 3.4877
# Epoch 9: saving model to /content/drive/MyDrive/Thesis/self_driving(simp1)/models(simp1)/BirdsEye_cat_simple-2-saved-model-09-3.72433.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 84s 329ms/step - categorical_accuracy: 0.8197 - loss: 3.4876 - val_categorical_accuracy: 0.8229 - val_loss: 3.7243 - learning_rate: 1.0000e-04
# Epoch 10/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - categorical_accuracy: 0.8238 - loss: 3.4367
# Epoch 10: saving model to /content/drive/MyDrive/Thesis/self_driving(simp1)/models(simp1)/BirdsEye_cat_simple-2-saved-model-10-3.61072.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 83s 325ms/step - categorical_accuracy: 0.8238 - loss: 3.4366 - val_categorical_accuracy: 0.8288 - val_loss: 3.6107 - learning_rate: 1.0000e-04
# Epoch 11/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - categorical_accuracy: 0.8271 - loss: 3.3914
# Epoch 11: saving model to /content/drive/MyDrive/Thesis/self_driving(simp1)/models(simp1)/BirdsEye_cat_simple-2-saved-model-11-3.48055.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 84s 329ms/step - categorical_accuracy: 0.8271 - loss: 3.3913 - val_categorical_accuracy: 0.8293 - val_loss: 3.4806 - learning_rate: 1.0000e-04
# Epoch 12/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - categorical_accuracy: 0.8345 - loss: 3.2917
# Epoch 12: saving model to /content/drive/MyDrive/Thesis/self_driving(simp1)/models(simp1)/BirdsEye_cat_simple-2-saved-model-12-3.43274.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 85s 334ms/step - categorical_accuracy: 0.8344 - loss: 3.2918 - val_categorical_accuracy: 0.8312 - val_loss: 3.4327 - learning_rate: 1.0000e-04
# Epoch 13/50
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - categorical_accuracy: 0.8354 - loss: 3.2507
# Epoch 13: saving model to /content/drive/MyDrive/Thesis/self_driving(simp1)/models(simp1)/BirdsEye_cat_simple-2-saved-model-13-3.27644.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 86s 338ms/step - categorical_accuracy: 0.8354 - loss: 3.2507 - val_categorical_accuracy: 0.8324 - val_loss: 3.2764 - learning_rate: 1.0000e-04
# Epoch 14/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step - categorical_accuracy: 0.8389 - loss: 3.2031
# Epoch 14: saving model to /content/drive/MyDrive/Thesis/self_driving(simp1)/models(simp1)/BirdsEye_cat_simple-2-saved-model-14-3.17811.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 87s 340ms/step - categorical_accuracy: 0.8389 - loss: 3.2031 - val_categorical_accuracy: 0.8353 - val_loss: 3.1781 - learning_rate: 1.0000e-04
# Epoch 15/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - categorical_accuracy: 0.8425 - loss: 3.1487
# Epoch 15: saving model to /content/drive/MyDrive/Thesis/self_driving(simp1)/models(simp1)/BirdsEye_cat_simple-2-saved-model-15-3.23561.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 87s 340ms/step - categorical_accuracy: 0.8425 - loss: 3.1487 - val_categorical_accuracy: 0.8331 - val_loss: 3.2356 - learning_rate: 1.0000e-04
# Epoch 16/50
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - categorical_accuracy: 0.8428 - loss: 3.1437
# Epoch 16: saving model to /content/drive/MyDrive/Thesis/self_driving(simp1)/models(simp1)/BirdsEye_cat_simple-2-saved-model-16-3.12796.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 87s 339ms/step - categorical_accuracy: 0.8428 - loss: 3.1436 - val_categorical_accuracy: 0.8401 - val_loss: 3.1280 - learning_rate: 1.0000e-04
# Epoch 17/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - categorical_accuracy: 0.8464 - loss: 3.0926
# Epoch 17: saving model to /content/drive/MyDrive/Thesis/self_driving(simp1)/models(simp1)/BirdsEye_cat_simple-2-saved-model-17-2.99828.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 86s 335ms/step - categorical_accuracy: 0.8464 - loss: 3.0926 - val_categorical_accuracy: 0.8425 - val_loss: 2.9983 - learning_rate: 1.0000e-04
# Epoch 18/50
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - categorical_accuracy: 0.8493 - loss: 3.0565
# Epoch 18: saving model to /content/drive/MyDrive/Thesis/self_driving(simp1)/models(simp1)/BirdsEye_cat_simple-2-saved-model-18-2.97813.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 85s 330ms/step - categorical_accuracy: 0.8493 - loss: 3.0566 - val_categorical_accuracy: 0.8440 - val_loss: 2.9781 - learning_rate: 1.0000e-04
# Epoch 19/50
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - categorical_accuracy: 0.8493 - loss: 3.0561
# Epoch 19: saving model to /content/drive/MyDrive/Thesis/self_driving(simp1)/models(simp1)/BirdsEye_cat_simple-2-saved-model-19-3.07311.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 84s 328ms/step - categorical_accuracy: 0.8493 - loss: 3.0561 - val_categorical_accuracy: 0.8421 - val_loss: 3.0731 - learning_rate: 1.0000e-04
# Epoch 20/50
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - categorical_accuracy: 0.8518 - loss: 3.0390
# Epoch 20: saving model to /content/drive/MyDrive/Thesis/self_driving(simp1)/models(simp1)/BirdsEye_cat_simple-2-saved-model-20-2.89656.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 84s 330ms/step - categorical_accuracy: 0.8518 - loss: 3.0389 - val_categorical_accuracy: 0.8467 - val_loss: 2.8966 - learning_rate: 1.0000e-04
# Epoch 21/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - categorical_accuracy: 0.8539 - loss: 3.0009
# Epoch 21: saving model to /content/drive/MyDrive/Thesis/self_driving(simp1)/models(simp1)/BirdsEye_cat_simple-2-saved-model-21-3.05402.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 84s 329ms/step - categorical_accuracy: 0.8539 - loss: 3.0009 - val_categorical_accuracy: 0.8442 - val_loss: 3.0540 - learning_rate: 1.0000e-04
# Epoch 22/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - categorical_accuracy: 0.8558 - loss: 2.9893
# Epoch 22: saving model to /content/drive/MyDrive/Thesis/self_driving(simp1)/models(simp1)/BirdsEye_cat_simple-2-saved-model-22-2.95647.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 83s 324ms/step - categorical_accuracy: 0.8558 - loss: 2.9892 - val_categorical_accuracy: 0.8461 - val_loss: 2.9565 - learning_rate: 1.0000e-04
# Epoch 23/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step - categorical_accuracy: 0.8562 - loss: 2.9848
# Epoch 23: saving model to /content/drive/MyDrive/Thesis/self_driving(simp1)/models(simp1)/BirdsEye_cat_simple-2-saved-model-23-3.02530.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 83s 324ms/step - categorical_accuracy: 0.8562 - loss: 2.9848 - val_categorical_accuracy: 0.8455 - val_loss: 3.0253 - learning_rate: 1.0000e-04
# Epoch 24/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - categorical_accuracy: 0.8603 - loss: 2.9290
# Epoch 24: saving model to /content/drive/MyDrive/Thesis/self_driving(simp1)/models(simp1)/BirdsEye_cat_simple-2-saved-model-24-3.09899.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 83s 324ms/step - categorical_accuracy: 0.8603 - loss: 2.9291 - val_categorical_accuracy: 0.8440 - val_loss: 3.0990 - learning_rate: 1.0000e-04
# Epoch 25/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step - categorical_accuracy: 0.8603 - loss: 2.9288
# Epoch 25: saving model to /content/drive/MyDrive/Thesis/self_driving(simp1)/models(simp1)/BirdsEye_cat_simple-2-saved-model-25-2.93156.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 321ms/step - categorical_accuracy: 0.8603 - loss: 2.9288 - val_categorical_accuracy: 0.8492 - val_loss: 2.9316 - learning_rate: 1.0000e-04
# Epoch 26/50
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - categorical_accuracy: 0.8618 - loss: 2.9044
# Epoch 26: saving model to /content/drive/MyDrive/Thesis/self_driving(simp1)/models(simp1)/BirdsEye_cat_simple-2-saved-model-26-2.95684.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 81s 317ms/step - categorical_accuracy: 0.8618 - loss: 2.9044 - val_categorical_accuracy: 0.8497 - val_loss: 2.9568 - learning_rate: 1.0000e-04
# Epoch 27/50
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - categorical_accuracy: 0.8625 - loss: 2.9095
# Epoch 27: saving model to /content/drive/MyDrive/Thesis/self_driving(simp1)/models(simp1)/BirdsEye_cat_simple-2-saved-model-27-2.86535.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 84s 327ms/step - categorical_accuracy: 0.8625 - loss: 2.9094 - val_categorical_accuracy: 0.8506 - val_loss: 2.8654 - learning_rate: 1.0000e-04
# Epoch 28/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step - categorical_accuracy: 0.8631 - loss: 2.9058
# Epoch 28: saving model to /content/drive/MyDrive/Thesis/self_driving(simp1)/models(simp1)/BirdsEye_cat_simple-2-saved-model-28-2.94570.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 87s 341ms/step - categorical_accuracy: 0.8631 - loss: 2.9057 - val_categorical_accuracy: 0.8506 - val_loss: 2.9457 - learning_rate: 1.0000e-04
# Epoch 29/50
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - categorical_accuracy: 0.8663 - loss: 2.8570
# Epoch 29: saving model to /content/drive/MyDrive/Thesis/self_driving(simp1)/models(simp1)/BirdsEye_cat_simple-2-saved-model-29-3.02121.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 86s 335ms/step - categorical_accuracy: 0.8662 - loss: 2.8570 - val_categorical_accuracy: 0.8511 - val_loss: 3.0212 - learning_rate: 1.0000e-04
# Epoch 30/50
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - categorical_accuracy: 0.8679 - loss: 2.8527
# Epoch 30: saving model to /content/drive/MyDrive/Thesis/self_driving(simp1)/models(simp1)/BirdsEye_cat_simple-2-saved-model-30-2.80158.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 90s 352ms/step - categorical_accuracy: 0.8679 - loss: 2.8528 - val_categorical_accuracy: 0.8565 - val_loss: 2.8016 - learning_rate: 1.0000e-04
# Epoch 31/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - categorical_accuracy: 0.8687 - loss: 2.8091
# Epoch 31: saving model to /content/drive/MyDrive/Thesis/self_driving(simp1)/models(simp1)/BirdsEye_cat_simple-2-saved-model-31-2.87384.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 83s 324ms/step - categorical_accuracy: 0.8687 - loss: 2.8092 - val_categorical_accuracy: 0.8531 - val_loss: 2.8738 - learning_rate: 1.0000e-04
# Epoch 32/50
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - categorical_accuracy: 0.8688 - loss: 2.8173
# Epoch 32: saving model to /content/drive/MyDrive/Thesis/self_driving(simp1)/models(simp1)/BirdsEye_cat_simple-2-saved-model-32-2.80668.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 81s 317ms/step - categorical_accuracy: 0.8688 - loss: 2.8173 - val_categorical_accuracy: 0.8563 - val_loss: 2.8067 - learning_rate: 1.0000e-04
# Epoch 33/50
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - categorical_accuracy: 0.8690 - loss: 2.8205
# Epoch 33: saving model to /content/drive/MyDrive/Thesis/self_driving(simp1)/models(simp1)/BirdsEye_cat_simple-2-saved-model-33-2.75993.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 80s 315ms/step - categorical_accuracy: 0.8690 - loss: 2.8204 - val_categorical_accuracy: 0.8584 - val_loss: 2.7599 - learning_rate: 1.0000e-04
# Epoch 34/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - categorical_accuracy: 0.8708 - loss: 2.7814
# Epoch 34: saving model to /content/drive/MyDrive/Thesis/self_driving(simp1)/models(simp1)/BirdsEye_cat_simple-2-saved-model-34-2.76448.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 81s 315ms/step - categorical_accuracy: 0.8708 - loss: 2.7815 - val_categorical_accuracy: 0.8556 - val_loss: 2.7645 - learning_rate: 1.0000e-04
# Epoch 35/50
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - categorical_accuracy: 0.8719 - loss: 2.7759
# Epoch 35: saving model to /content/drive/MyDrive/Thesis/self_driving(simp1)/models(simp1)/BirdsEye_cat_simple-2-saved-model-35-2.81905.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 81s 319ms/step - categorical_accuracy: 0.8719 - loss: 2.7759 - val_categorical_accuracy: 0.8533 - val_loss: 2.8191 - learning_rate: 1.0000e-04
# Epoch 36/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - categorical_accuracy: 0.8720 - loss: 2.7769
# Epoch 36: saving model to /content/drive/MyDrive/Thesis/self_driving(simp1)/models(simp1)/BirdsEye_cat_simple-2-saved-model-36-2.73701.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 80s 314ms/step - categorical_accuracy: 0.8720 - loss: 2.7769 - val_categorical_accuracy: 0.8566 - val_loss: 2.7370 - learning_rate: 1.0000e-04
# Epoch 37/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - categorical_accuracy: 0.8726 - loss: 2.7395
# Epoch 37: saving model to /content/drive/MyDrive/Thesis/self_driving(simp1)/models(simp1)/BirdsEye_cat_simple-2-saved-model-37-2.81169.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 80s 313ms/step - categorical_accuracy: 0.8726 - loss: 2.7396 - val_categorical_accuracy: 0.8576 - val_loss: 2.8117 - learning_rate: 1.0000e-04
# Epoch 38/50
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - categorical_accuracy: 0.8738 - loss: 2.7529
# Epoch 38: saving model to /content/drive/MyDrive/Thesis/self_driving(simp1)/models(simp1)/BirdsEye_cat_simple-2-saved-model-38-2.72193.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 80s 312ms/step - categorical_accuracy: 0.8738 - loss: 2.7529 - val_categorical_accuracy: 0.8590 - val_loss: 2.7219 - learning_rate: 1.0000e-04
# Epoch 39/50
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - categorical_accuracy: 0.8744 - loss: 2.7515
# Epoch 39: saving model to /content/drive/MyDrive/Thesis/self_driving(simp1)/models(simp1)/BirdsEye_cat_simple-2-saved-model-39-2.78807.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 81s 318ms/step - categorical_accuracy: 0.8744 - loss: 2.7515 - val_categorical_accuracy: 0.8584 - val_loss: 2.7881 - learning_rate: 1.0000e-04
# Epoch 40/50
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - categorical_accuracy: 0.8767 - loss: 2.7133
# Epoch 40: saving model to /content/drive/MyDrive/Thesis/self_driving(simp1)/models(simp1)/BirdsEye_cat_simple-2-saved-model-40-2.82002.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 81s 316ms/step - categorical_accuracy: 0.8767 - loss: 2.7134 - val_categorical_accuracy: 0.8563 - val_loss: 2.8200 - learning_rate: 1.0000e-04
# Epoch 41/50
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - categorical_accuracy: 0.8772 - loss: 2.7231
# Epoch 41: saving model to /content/drive/MyDrive/Thesis/self_driving(simp1)/models(simp1)/BirdsEye_cat_simple-2-saved-model-41-2.87251.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 81s 316ms/step - categorical_accuracy: 0.8772 - loss: 2.7230 - val_categorical_accuracy: 0.8602 - val_loss: 2.8725 - learning_rate: 1.0000e-04
# Epoch 42/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - categorical_accuracy: 0.8777 - loss: 2.7044
# Epoch 42: saving model to /content/drive/MyDrive/Thesis/self_driving(simp1)/models(simp1)/BirdsEye_cat_simple-2-saved-model-42-2.79473.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 82s 320ms/step - categorical_accuracy: 0.8777 - loss: 2.7044 - val_categorical_accuracy: 0.8577 - val_loss: 2.7947 - learning_rate: 1.0000e-04
# Epoch 43/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - categorical_accuracy: 0.8774 - loss: 2.7157
# Epoch 43: saving model to /content/drive/MyDrive/Thesis/self_driving(simp1)/models(simp1)/BirdsEye_cat_simple-2-saved-model-43-2.76359.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 80s 314ms/step - categorical_accuracy: 0.8774 - loss: 2.7156 - val_categorical_accuracy: 0.8617 - val_loss: 2.7636 - learning_rate: 1.0000e-04
# Epoch 44/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - categorical_accuracy: 0.8803 - loss: 2.6747
# Epoch 44: saving model to /content/drive/MyDrive/Thesis/self_driving(simp1)/models(simp1)/BirdsEye_cat_simple-2-saved-model-44-2.78611.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 81s 315ms/step - categorical_accuracy: 0.8803 - loss: 2.6748 - val_categorical_accuracy: 0.8617 - val_loss: 2.7861 - learning_rate: 1.0000e-04
# Epoch 45/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - categorical_accuracy: 0.8797 - loss: 2.6772
# Epoch 45: saving model to /content/drive/MyDrive/Thesis/self_driving(simp1)/models(simp1)/BirdsEye_cat_simple-2-saved-model-45-2.77352.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 81s 318ms/step - categorical_accuracy: 0.8797 - loss: 2.6773 - val_categorical_accuracy: 0.8611 - val_loss: 2.7735 - learning_rate: 1.0000e-04
# Epoch 46/50
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - categorical_accuracy: 0.8806 - loss: 2.6737
# Epoch 46: saving model to /content/drive/MyDrive/Thesis/self_driving(simp1)/models(simp1)/BirdsEye_cat_simple-2-saved-model-46-2.82373.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 81s 318ms/step - categorical_accuracy: 0.8806 - loss: 2.6738 - val_categorical_accuracy: 0.8591 - val_loss: 2.8237 - learning_rate: 1.0000e-04
# Epoch 47/50
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - categorical_accuracy: 0.8794 - loss: 2.6716
# Epoch 47: saving model to /content/drive/MyDrive/Thesis/self_driving(simp1)/models(simp1)/BirdsEye_cat_simple-2-saved-model-47-2.68160.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 80s 314ms/step - categorical_accuracy: 0.8794 - loss: 2.6716 - val_categorical_accuracy: 0.8641 - val_loss: 2.6816 - learning_rate: 1.0000e-04
# Epoch 48/50
# 249/250 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - categorical_accuracy: 0.8811 - loss: 2.6572
# Epoch 48: saving model to /content/drive/MyDrive/Thesis/self_driving(simp1)/models(simp1)/BirdsEye_cat_simple-2-saved-model-48-2.69410.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 80s 311ms/step - categorical_accuracy: 0.8811 - loss: 2.6571 - val_categorical_accuracy: 0.8606 - val_loss: 2.6941 - learning_rate: 1.0000e-04
# Epoch 49/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - categorical_accuracy: 0.8815 - loss: 2.6467
# Epoch 49: saving model to /content/drive/MyDrive/Thesis/self_driving(simp1)/models(simp1)/BirdsEye_cat_simple-2-saved-model-49-2.71397.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 78s 307ms/step - categorical_accuracy: 0.8815 - loss: 2.6467 - val_categorical_accuracy: 0.8640 - val_loss: 2.7140 - learning_rate: 1.0000e-04
# Epoch 50/50
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - categorical_accuracy: 0.8824 - loss: 2.6515
# Epoch 50: saving model to /content/drive/MyDrive/Thesis/self_driving(simp1)/models(simp1)/BirdsEye_cat_simple-2-saved-model-50-2.69126.keras
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 79s 309ms/step - categorical_accuracy: 0.8824 - loss: 2.6515 - val_categorical_accuracy: 0.8633 - val_loss: 2.6913 - learning_rate: 1.0000e-04
# History saved at /content/drive/MyDrive/Thesis/self_driving(simp1)/history/history.pkl

# %% [markdown]
# ###Validation

# %%
from keras.models import load_model

model = load_model('/content/drive/MyDrive/Thesis/self_driving(simp1)/models(simp1)/BirdsEye_cat_simple-2-saved-model-50-2.69126.keras', compile=False)

# %%
X, y = val_generator.__getitem__(400)
print(X.shape, y.shape)
# Out:
# (1, 96, 144, 7) (1, 96, 72, 7)

# %%
fig=plt.figure(figsize=(17, 17))
columns = 4
rows = 2

for i in range(1, columns*rows + 1):
    img = X[0]
    fig.add_subplot(rows, columns, i)
    plt.imshow(categorical_to_img(img), cmap='gist_stern', vmin=0, vmax=len(needed_labels) - 1)
plt.show()

# %%
fig=plt.figure(figsize=(17, 17))
columns = 4
rows = 2
for i in range(1, columns*rows + 1):
    img = X[0]
    pred = model.predict(np.array([img]))
    fig.add_subplot(rows, columns, i)
    plt.imshow(np.rot90(categorical_to_img(pred[0]), 3), cmap='gist_stern', vmin=0, vmax=len(needed_labels)-1)
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step

# %%
fig=plt.figure(figsize=(17, 17))
columns = 4
rows = 2
for i in range(1, columns*rows + 1):
    img = y[0]
    fig.add_subplot(rows, columns, i)
    plt.imshow(np.rot90(categorical_to_img(img), 3), cmap='gist_stern', vmin=0, vmax=len(needed_labels)-1)

# %%
import pickle

# Load the history from the .pkl file
with open('/content/drive/MyDrive/Thesis/self_driving(simp1)/history/history.pkl', 'rb') as f:
    history = pickle.load(f)

# Check the available keys in the history
print(history.keys())
# Out:
# dict_keys(['categorical_accuracy', 'loss', 'val_categorical_accuracy', 'val_loss', 'learning_rate'])

# %%
# Required Imports
import matplotlib.pyplot as plt
import numpy as np
from keras.models import load_model
import pickle

# Path to Saved Model
model_path = "/content/drive/MyDrive/Thesis/self_driving(simp1)/models(simp1)/BirdsEye_cat_simple-2-saved-model-50-2.69126.keras"

# Load the Model with Custom Loss Functions
model = load_model(
    model_path,
    custom_objects={
        'custom_loss': custom_loss,
        'dice_coef_multilabel': dice_coef_multilabel
    }
)

# Load Training History
history_path = '/content/drive/MyDrive/Thesis/self_driving(simp1)/history/history.pkl'
with open(history_path, 'rb') as f:
    history = pickle.load(f)

# Load enough samples from the validation generator
num_samples = 5  # Desired number of samples
X, y = val_generator.__getitem__(0)
for i in range(1, num_samples):
    X_temp, y_temp = val_generator.__getitem__(i)
    X = np.concatenate([X, X_temp])
    y = np.concatenate([y, y_temp])

# 1. Loss Curve
def plot_loss_curve(history):
    plt.figure(figsize=(8, 6))
    plt.plot(history['loss'], label='Training Loss', color='blue')
    plt.plot(history['val_loss'], label='Validation Loss', color='orange')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

# 2. Accuracy Curve (Categorical Accuracy)
def plot_accuracy_curve(history):
    plt.figure(figsize=(8, 6))
    plt.plot(history['categorical_accuracy'], label='Training Accuracy', color='blue')
    plt.plot(history['val_categorical_accuracy'], label='Validation Accuracy', color='orange')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.legend()
    plt.grid(True)
    plt.show()

# 3. Sample Segmentation Results
def plot_sample_segmentation_results(model, X, y, num_samples=5):
    fig, axes = plt.subplots(3, num_samples, figsize=(20, 10))
    for i in range(num_samples):
        input_image = X[i]
        true_mask = np.argmax(y[i], axis=-1)
        predicted_mask = np.argmax(model.predict(np.array([input_image]))[0], axis=-1)

        # Convert input image to grayscale for display
        input_image_gray = np.mean(input_image, axis=-1)

        axes[0, i].imshow(categorical_to_img(input_image), cmap='gist_stern', vmin=0, vmax=len(needed_labels) - 1)
        axes[0, i].set_title(f'Input Image {i+1}')
        axes[0, i].axis('off')

        axes[1, i].imshow(true_mask, cmap='gist_stern')
        axes[1, i].set_title(f'Ground Truth {i+1}')
        axes[1, i].axis('off')

        axes[2, i].imshow(predicted_mask, cmap='gist_stern')
        axes[2, i].set_title(f'Prediction {i+1}')
        axes[2, i].axis('off')

    plt.tight_layout()
    plt.show()

# 4. Error Visualization
def plot_error_visualization(model, X, y, sample_index=0):
    input_image = X[sample_index]
    true_mask = np.argmax(y[sample_index], axis=-1)
    predicted_mask = np.argmax(model.predict(np.array([input_image]))[0], axis=-1)
    error_map = np.abs(true_mask - predicted_mask)

    fig, axes = plt.subplots(1, 3, figsize=(15, 5))

    input_image_gray = np.mean(input_image, axis=-1)
    axes[0].imshow(categorical_to_img(input_image), cmap='gist_stern', vmin=0, vmax=len(needed_labels) - 1)
    axes[0].set_title('Input Image')
    axes[0].axis('off')

    axes[1].imshow(true_mask, cmap='gist_stern')
    axes[1].set_title('Ground Truth Mask')
    axes[1].axis('off')

    axes[2].imshow(error_map, cmap='hot')
    axes[2].set_title('Error Map')
    axes[2].axis('off')

    plt.tight_layout()
    plt.show()

# 5. Learning Rate Schedule
def plot_learning_rate_schedule(history):
    plt.figure(figsize=(8, 6))
    plt.plot(history['learning_rate'], label='Learning Rate', color='green')
    plt.xlabel('Epochs')
    plt.ylabel('Learning Rate')
    plt.title('Learning Rate Schedule')
    plt.grid(True)
    plt.legend()
    plt.show()

# %%
plot_loss_curve(history)

# %%
plot_accuracy_curve(history)

# %%
plot_sample_segmentation_results(model, X, y, num_samples=num_samples)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step

# %%
plot_error_visualization(model, X, y, sample_index=0)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step

# %%
plot_learning_rate_schedule(history)

# %%
# Calculate Percentage Improvements
training_loss_reduction = ((history['loss'][0] - history['loss'][-1]) / history['loss'][0]) * 100
validation_loss_reduction = ((history['val_loss'][0] - history['val_loss'][-1]) / history['val_loss'][0]) * 100
training_accuracy_improvement = ((history['categorical_accuracy'][-1] - history['categorical_accuracy'][0]) / history['categorical_accuracy'][0]) * 100
validation_accuracy_improvement = ((history['val_categorical_accuracy'][-1] - history['val_categorical_accuracy'][0]) / history['val_categorical_accuracy'][0]) * 100

# Print Improvements
print(f"Training Loss Reduction: {training_loss_reduction:.2f}%")
print(f"Validation Loss Reduction: {validation_loss_reduction:.2f}%")
print(f"Training Accuracy Improvement: {training_accuracy_improvement:.2f}%")
print(f"Validation Accuracy Improvement: {validation_accuracy_improvement:.2f}%")
# Out:
# Training Loss Reduction: 61.84%
# Validation Loss Reduction: 52.89%
# Training Accuracy Improvement: 70.97%
# Validation Accuracy Improvement: 21.69%

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the class labels for better clarity in reporting
LABELS = {
    0: 'None',
    1: 'Buildings',
    2: 'Fences',
    3: 'Other',
    4: 'Pedestrians',
    5: 'Poles',
    6: 'RoadLines',
    7: 'Roads',
    8: 'Sidewalks',
    9: 'Vegetation',
    10: 'Vehicles',
    11: 'Walls',
    12: 'TrafficSigns',
}

def compute_miou(prediction, ground_truth, num_classes):
    """
    Computes Mean Intersection over Union (mIoU) for a single prediction and ground truth pair.
    :param prediction: Predicted mask.
    :param ground_truth: Ground truth mask.
    :param num_classes: Number of classes.
    :return: mIoU and IoU per class.
    """
    iou_per_class = np.zeros(num_classes)
    for c in range(num_classes):
        intersection = np.sum((prediction == c) & (ground_truth == c))
        union = np.sum((prediction == c) | (ground_truth == c))
        if union > 0:
            iou_per_class[c] = intersection / union
    miou = np.nanmean(iou_per_class)
    return miou, iou_per_class

def plot_final_comparison_with_miou(model, generator, sample_index=500, num_classes=len(LABELS)):
    """
    Visualizes the input image, ground truth, and model prediction for a single sample,
    and calculates mIoU.
    :param model: Trained model for prediction.
    :param generator: Data generator providing input and ground truth.
    :param sample_index: Index of the batch in the generator to visualize.
    :param num_classes: Number of classes for mIoU calculation.
    """
    # Load a batch of data
    X, y = generator.__getitem__(1573)  # Get a batch from the generator
    input_image = X[0]  # Select the first image in the batch
    ground_truth = np.argmax(y[0], axis=-1)  # Convert one-hot encoded ground truth to class indices

    # Generate the model prediction
    predicted_mask = np.argmax(model.predict(np.array([input_image]))[0], axis=-1)

    # Compute mIoU
    miou, iou_per_class = compute_miou(predicted_mask, ground_truth, num_classes)

    # Create a figure to display the results
    fig, axes = plt.subplots(1, 3, figsize=(18, 6))

    # Convert input image to grayscale for better visualization
    input_image_gray = np.mean(input_image, axis=-1)

    # Input image
    axes[0].imshow(categorical_to_img(input_image), cmap='gist_stern', vmin=0, vmax=len(needed_labels) - 1)
    axes[0].set_title("Front View (Input)")
    axes[0].axis("off")

    # Ground truth
    axes[1].imshow(ground_truth, cmap="gist_stern")
    axes[1].set_title("Ground Truth")
    axes[1].axis("off")

    # Predicted result
    axes[2].imshow(predicted_mask, cmap="gist_stern")
    axes[2].set_title(f"Prediction (mIoU: {miou:.2f})")
    axes[2].axis("off")

    plt.tight_layout()
    plt.show()

    # Print detailed IoU per class with labels
    print(f"Mean IoU (mIoU): {miou:.2f}")
    print("IoU per class:")
    for c, iou in enumerate(iou_per_class):
        class_name = LABELS.get(c, f"Class {c}")
        print(f"  {class_name}: {iou:.2f}")

# Example Usage
# Assuming `model` is your trained model and `val_generator` is the validation data generator
plot_final_comparison_with_miou(model, val_generator, sample_index=0, num_classes=len(LABELS))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Mean IoU (mIoU): 0.28
# IoU per class:
#   None: 0.78
#   Buildings: 0.62
#   Fences: 0.41
#   Other: 0.76
#   Pedestrians: 0.79
#   Poles: 0.21
#   RoadLines: 0.00
#   Roads: 0.00
#   Sidewalks: 0.00
#   Vegetation: 0.00
#   Vehicles: 0.00
#   Walls: 0.00
#   TrafficSigns: 0.00

# %%
import matplotlib.pyplot as plt
import numpy as np
import random

def compute_miou(prediction, ground_truth, num_classes):
    """
    Computes Mean Intersection over Union (mIoU) for a single prediction and ground truth pair.
    :param prediction: Predicted mask.
    :param ground_truth: Ground truth mask.
    :param num_classes: Number of classes.
    :return: mIoU and IoU per class.
    """
    iou_per_class = np.zeros(num_classes)
    for c in range(num_classes):
        intersection = np.sum((prediction == c) & (ground_truth == c))
        union = np.sum((prediction == c) | (ground_truth == c))
        if union > 0:
            iou_per_class[c] = intersection / union
    miou = np.nanmean(iou_per_class)
    return miou, iou_per_class

def plot_and_compute_miou_for_batches(model, generator, num_batches=5, num_classes=len(LABELS)):
    """
    Processes multiple random batches, visualizes each batch, and computes the average mIoU.
    :param model: Trained model for prediction.
    :param generator: Data generator providing input and ground truth.
    :param num_batches: Number of random batches to process.
    :param num_classes: Number of classes for mIoU calculation.
    """
    random_batches = random.sample(range(len(generator)), num_batches)  # Randomly select batch indices
    miou_values = []  # To store mIoU values for averaging

    for batch_index in random_batches:
        # Load the specific batch
        X, y = generator.__getitem__(batch_index)
        input_image = X[0]  # First (and only) image in the batch
        ground_truth = np.argmax(y[0], axis=-1)  # Convert one-hot encoded ground truth to class indices

        # Generate the model prediction
        predicted_mask = np.argmax(model.predict(np.array([input_image]))[0], axis=-1)

        # Compute mIoU
        miou, iou_per_class = compute_miou(predicted_mask, ground_truth, num_classes)
        miou_values.append(miou)

        # Create a figure to display the results
        fig, axes = plt.subplots(1, 3, figsize=(18, 6))

        # Convert input image to grayscale for better visualization
        input_image_gray = np.mean(input_image, axis=-1)

        # Input image
        axes[0].imshow(categorical_to_img(input_image), cmap='gist_stern', vmin=0, vmax=len(needed_labels) - 1)
        axes[0].set_title("Front View (Input)")
        axes[0].axis("off")

        # Ground truth
        axes[1].imshow(ground_truth, cmap="gist_stern")
        axes[1].set_title("Ground Truth")
        axes[1].axis("off")

        # Predicted result
        axes[2].imshow(predicted_mask, cmap="gist_stern")
        axes[2].set_title(f"Prediction (mIoU: {miou:.2f})")
        axes[2].axis("off")

        plt.tight_layout()
        plt.show()

        # Print detailed IoU per class with labels
        print(f"Batch {batch_index}:")
        print(f"Mean IoU (mIoU): {miou:.2f}")
        print("IoU per class:")
        for c, iou in enumerate(iou_per_class):
            class_name = LABELS.get(c, f"Class {c}")
            print(f"  {class_name}: {iou:.2f}")
        print("\n")

    # Calculate and display the average mIoU
    average_miou = np.mean(miou_values)
    print(f"Average mIoU across {num_batches} batches: {average_miou:.2f}")

# Example Usage
# Assuming `model` is your trained model and `val_generator` is the validation data generator
plot_and_compute_miou_for_batches(model, val_generator, num_batches=5, num_classes=len(LABELS))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Batch 343:
# Mean IoU (mIoU): 0.16
# IoU per class:
#   None: 0.75
#   Buildings: 0.00
#   Fences: 0.00
#   Other: 0.63
#   Pedestrians: 0.38
#   Poles: 0.34
#   RoadLines: 0.00
#   Roads: 0.00
#   Sidewalks: 0.00
#   Vegetation: 0.00
#   Vehicles: 0.00
#   Walls: 0.00
#   TrafficSigns: 0.00
#
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Batch 404:
# Mean IoU (mIoU): 0.34
# IoU per class:
#   None: 0.87
#   Buildings: 0.28
#   Fences: 0.45
#   Other: 0.92
#   Pedestrians: 0.87
#   Poles: 0.97
#   RoadLines: 0.00
#   Roads: 0.00
#   Sidewalks: 0.00
#   Vegetation: 0.00
#   Vehicles: 0.00
#   Walls: 0.00
#   TrafficSigns: 0.00
#
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Batch 390:
# Mean IoU (mIoU): 0.24
# IoU per class:
#   None: 0.55
#   Buildings: 0.00
#   Fences: 0.22
#   Other: 0.77
#   Pedestrians: 0.55
#   Poles: 1.00
#   RoadLines: 0.00
#   Roads: 0.00
#   Sidewalks: 0.00
#   Vegetation: 0.00
#   Vehicles: 0.00
#   Walls: 0.00
#   TrafficSigns: 0.00
#
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Batch 1874:
# Mean IoU (mIoU): 0.19
# IoU per class:
#   None: 0.67
#   Buildings: 0.00
#   Fences: 0.09
#   Other: 0.76
#   Pedestrians: 0.49
#   Poles: 0.41
#   RoadLines: 0.00
#   Roads: 0.00
#   Sidewalks: 0.00
#   Vegetation: 0.00
#   Vehicles: 0.00
#   Walls: 0.00
#   TrafficSigns: 0.00
#
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Batch 248:
# Mean IoU (mIoU): 0.33
# IoU per class:
#   None: 0.97
#   Buildings: 0.00
#   Fences: 0.46
#   Other: 0.93
#   Pedestrians: 0.91
#   Poles: 0.97
#   RoadLines: 0.00
#   Roads: 0.00
#   Sidewalks: 0.00
#   Vegetation: 0.00
#   Vehicles: 0.00
#   Walls: 0.00
#   TrafficSigns: 0.00
#
#
# Average mIoU across 5 batches: 0.25

# %%
import numpy as np
import tensorflow as tf

# Define class labels
LABELS = {
    0: 'None',
    1: 'Buildings',
    2: 'Fences',
    3: 'Other',
    4: 'Pedestrians',
    5: 'Poles',
    6: 'RoadLines',
    7: 'Roads',
    8: 'Sidewalks',
    9: 'Vegetation',
    10: 'Vehicles',
    11: 'Walls',
    12: 'TrafficSigns',
}

def compute_iou(prediction, ground_truth, num_classes):
    """
    Computes IoU per class and mIoU for a single sample.
    :param prediction: Predicted mask.
    :param ground_truth: Ground truth mask.
    :param num_classes: Number of classes.
    :return: mIoU and IoU per class.
    """
    iou_per_class = np.zeros(num_classes)

    for c in range(num_classes):
        intersection = np.sum((prediction == c) & (ground_truth == c))
        union = np.sum((prediction == c) | (ground_truth == c))

        if union > 0:
            iou_per_class[c] = intersection / union  # Compute IoU for class c

    miou = np.nanmean(iou_per_class)  # Compute mean IoU ignoring NaN values
    return miou, iou_per_class

# Extract number of classes from LABELS
num_classes = len(LABELS)

# Initialize variables
total_iou = np.zeros(num_classes)  # Sum IoU values for averaging later
total_miou = []  # Store mIoU for each sample
num_samples = min(len(val_generator), 2000)  # Limit to 2000 samples

print("\nProcessing validation samples...")

# Iterate over validation dataset (limited to 2000 samples)
for i in range(num_samples):
    # Load input image and ground truth from val_generator
    X, y = val_generator.__getitem__(i)
    input_image = X[0]  # Extract image from batch
    ground_truth = np.argmax(y[0], axis=-1)  # Convert one-hot to class indices

    # Generate model prediction (Suppress print statements from TensorFlow)
    predicted_mask = np.argmax(model.predict(np.array([input_image]), verbose=0)[0], axis=-1)

    # Compute IoU and mIoU
    miou, iou_per_class = compute_iou(predicted_mask, ground_truth, num_classes)

    # Accumulate IoU values
    total_iou += np.nan_to_num(iou_per_class)  # Convert NaN to zero for summation
    total_miou.append(miou)  # Store mIoU

    # Print progress every 200 samples
    if (i + 1) % 200 == 0:
        print(f"✅ Processed {i + 1}/{num_samples} samples...")

# Compute final metrics
mean_iou_per_class = total_iou / num_samples  # Average IoU per class
mean_miou = np.nanmean(total_miou)  # Compute overall mean IoU

# Print results
print("\n🔹 **Mean IoU per Class:**")
for c, iou in enumerate(mean_iou_per_class):
    class_name = LABELS.get(c, f"Class {c}")
    print(f"  {class_name}: {iou:.4f}")

print(f"\n🔹 **Overall mIoU:** {mean_miou:.4f}")
print("\n✅ IoU evaluation completed!")
# Out:
# Processing validation samples...
# ✅ Processed 200/2000 samples...
# ✅ Processed 400/2000 samples...
# ✅ Processed 600/2000 samples...
# ✅ Processed 800/2000 samples...
# ✅ Processed 1000/2000 samples...
# ✅ Processed 1200/2000 samples...
# ✅ Processed 1400/2000 samples...
# ✅ Processed 1600/2000 samples...
# ✅ Processed 1800/2000 samples...
# ✅ Processed 2000/2000 samples...
#
# 🔹 **Mean IoU per Class:**
#   None: 0.7629
#   Buildings: 0.2301
#   Fences: 0.3769
#   Other: 0.8596
#   Pedestrians: 0.7146
#   Poles: 0.7693
#   RoadLines: 0.0136
#   Roads: 0.0000
#   Sidewalks: 0.0000
#   Vegetation: 0.0000
#   Vehicles: 0.0000
#   Walls: 0.0000
#   TrafficSigns: 0.0000
#
# 🔹 **Overall mIoU:** 0.2867
#
# ✅ IoU evaluation completed!

# %%
import numpy as np
import tensorflow as tf
from keras.models import load_model

# Path to your trained model (modify if needed)
model_path = "/content/drive/MyDrive/Thesis/self_driving(simp1)/models(simp1)/BirdsEye_cat_simple-2-saved-model-50-2.69126.keras"

# Load the model without compilation (since it’s only for inference)
model = load_model(model_path, compile=False)

print("✅ Model Loaded Successfully!")
# Out:
# ✅ Model Loaded Successfully!

# %%
# Define sample index (Change this to test different samples)
sample_index = 248  # Modify this to process other images

# Get input image (X) and ground truth (y) from validation generator
X, y = val_generator.__getitem__(sample_index)

# Convert one-hot encoded ground truth to class indices
ground_truth = np.argmax(y[0], axis=-1)

# Generate model prediction
predicted_mask = np.argmax(model.predict(np.array([X[0]]), verbose=0)[0], axis=-1)

# Save the extracted data to Google Drive
np.save(f"/content/drive/MyDrive/input_image_{sample_index}.npy", X[0])  # Save input image
np.save(f"/content/drive/MyDrive/ground_truth_{sample_index}.npy", ground_truth)  # Save ground truth mask
np.save(f"/content/drive/MyDrive/predicted_mask_{sample_index}.npy", predicted_mask)  # Save predicted mask

print(f"✅ Data saved for sample index {sample_index}:")
print(f"- input_image_{sample_index}.npy")
print(f"- ground_truth_{sample_index}.npy")
print(f"- predicted_mask_{sample_index}.npy")
# Out:
# ✅ Data saved for sample index 248:
# - input_image_248.npy
# - ground_truth_248.npy
# - predicted_mask_248.npy
